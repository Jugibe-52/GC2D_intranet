# %% [markdown]
# # Visualize saved Poincare results
#
# This notebook only loads checksum-verified saved products. It never integrates trajectories. The plot and offline particle selector retain the original particle IDs and colors. Numerical outputs and executed notebooks stay in this study folder.

# %%
import os
from IPython.display import display, Image, IFrame
from poincare_batch import render_saved
RUN_ID = os.environ.get('POINCARE_RUN_ID') or None
selector = render_saved(RUN_ID)
display(Image(filename=str(selector.parent/'poincare_section.png')))
display(Image(filename=str(selector.parent/'diagnostics.png')))
display(IFrame(str(selector.relative_to(selector.parents[2])),width='100%',height=1100))
# Out:
# Saved plots and particle selector: /home/juan/Proyectos/GC2D_intranet/notebooks/developements/poincare_section/Poincare_BM4Midpoint_48_radiales_5000_ciclos_20_steps_spot/figuras/aws_bm4midpoint_48p_5000c_20s_20260920
#         <iframe
#             width="100%"
#             height="1100"
#             src="figuras/aws_bm4midpoint_48p_5000c_20s_20260920/poincare_selector.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
